# %%
from sql import SQLConnector
from visualization import EarthquakeVisualizer

# %%
conn = SQLConnector()

# %%
visualizer = EarthquakeVisualizer(conn)

# %% [markdown]
# ## 1. histogram

# %%
visualizer.plot_magnitude_histogram()

# %% [markdown]
# ## 2. line plots

# %%
visualizer.plot_time_trends()

# %% [markdown]
# ## 3. Scatter Plot

# %%
visualizer.plot_scatter()

# %% [markdown]
# ## 4. BoxPlot

# %%
visualizer.plot_box_distribution()

# %% [markdown]
# ## 5. Heatmap

# %%
visualizer.plot_heatmap()
